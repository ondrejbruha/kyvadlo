# %% [markdown]
# # Matematické kyvadlo
# - Mechanický systém popsaný rovnicí:
# ![Rovnice](img.png)
# - Přibližné řešení (pro theta << 1):
# ![Přibližné řešení](img_1.png)
# ![Přibližné řešení](img_2.png)
#
# ## Numerické řešení obecného případu:

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import solve_ivp

g = 9.81
l = 10.2
theta0 = np.pi / 4
omega0 = 0  #1.8


def pendulum(t, y):
    theta, omega = y
    dtheta_dt = omega
    domega_dt = - (g / l) * np.sin(theta)
    return [dtheta_dt, domega_dt]


y0 = [theta0, omega0]

t_span = (0, 100)
t_eval = np.linspace(*t_span, 1000)

solution = solve_ivp(pendulum, t_span, y0, t_eval=t_eval, method='RK45')

theta = solution.y[0]
omega = solution.y[1]
time = solution.t

plt.figure(figsize=(10, 5))

plt.subplot(2, 1, 1)
plt.plot(time, theta)
plt.title('Graf kyvadla s nulovou počáteční rychlsotí')
plt.xlabel('Čas')
plt.ylabel('Výchylka')

plt.subplot(2, 1, 2)
plt.plot(time, omega)
plt.xlabel('Čas')
plt.ylabel('Úhlová rychlost')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Nenulová počátečí rychlost

# %%
omega0 = 1.8

y0 = [theta0, omega0]

t_span = (0, 100)
t_eval = np.linspace(*t_span, 1000)

solution = solve_ivp(pendulum, t_span, y0, t_eval=t_eval, method='RK45')

theta = solution.y[0]
omega = solution.y[1]
time = solution.t

plt.figure(figsize=(10, 5))

plt.subplot(2, 1, 1)
plt.plot(time, theta)
plt.title('Graf kyvadla s počáteční rychlostí 1.8 rad / s')
plt.xlabel('Čas')
plt.ylabel('Výchylka')

plt.subplot(2, 1, 2)
plt.plot(time, omega)
plt.xlabel('Čas')
plt.ylabel('Úhlová rychlost')

plt.tight_layout()
plt.show()
